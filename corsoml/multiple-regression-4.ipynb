# %%
import numpy as np
import matplotlib.pyplot as plt
# data generation
n=7
X = np.linspace(-20,20,n)
Y = 25 + 0.5*X**2 + 0.3*X -0.042*(X**3)
factor = 10
Y = (0.1*(X+4)**2 - 0.07*(X**3) - 20)/factor #+ (np.random.randint(-10,10,n))/10
xWanted = np.linspace(-20,20,100)
yWanted = (0.1*(xWanted+4)**2 - 0.07*(xWanted**3) - 20)/factor
# plot
plt.scatter(X, Y)
plt.scatter(xWanted,yWanted, color="red", alpha=0.2)
plt.show()

# %%
features = np.array([lambda _: 1,
                     lambda x: x,
                     lambda x: x**2,
                     lambda x: x**3,
                     lambda x: x**4,
                     lambda x: x**5,
                     lambda x: x**6,
                     lambda x: x**7,
                     lambda x: x**8,
                     lambda x: x**9,
                     lambda x: x**10,
                     lambda x: x**11,])
totEpochsDone = 0

# %%
epochs = 3000000
alpha = 0.000000000000000000000000000001
# W = np.zeros(len(features))
phi = np.matrix([[f(x) for f in features] for x in X])
for epoch in range(epochs):
    totEpochsDone += 1
    gradient = []
    pred = np.array([sum([w*f(x) for f,w in zip(features,W)]) for x in X])
    error = Y - pred
    for f in features:
        phi_x = np.array([f(x) for x in X])
        d = np.sum(phi_x * error)
        gradient.append(d)
    g = np.array(gradient)
    norm = np.linalg.norm(gradient)
    g *= alpha
    W += g
    if totEpochsDone%2500 == 0:
        print("\r",int(100*(epoch/epochs)),"%", " --- ", totEpochsDone, " epochs --- norm: ", norm, end="", sep="")
print()
print(W)
# Out:
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# (7, 1)
# ...

# %%
manyX = np.linspace(-20,20,100)
plt.scatter(xWanted,yWanted, color="red", alpha=0.3)
Z = [sum([w*f(x) for w,f in zip(W,features)]) for x in manyX]
plt.scatter(manyX, Z, color="green", alpha=0.3)
plt.scatter(X, Y)
plt.show()
